# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
b = pd.read_csv('Berkeley.csv')

# %%
bd = pd.DataFrame(b)

# %%
bd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 4 columns):
# Admit     24 non-null object
# Gender    24 non-null object
# Dept      24 non-null object
# Freq      24 non-null int64
# dtypes: int64(1), object(3)
# memory usage: 840.0+ bytes

# %%
bd.head()
# Out:
#       Admit  Gender Dept  Freq
# 0  Admitted    Male    A   512
# 1  Rejected    Male    A   313
# 2  Admitted  Female    A    89
# 3  Rejected  Female    A    19
# 4  Admitted    Male    B   353

# %%
bd.describe()
# Out:
#              Freq
# count   24.000000
# mean   188.583333
# std    140.063624
# min      8.000000
# 25%     80.000000
# 50%    170.000000
# 75%    302.500000
# max    512.000000

# %%
bd.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10edc4ad0>]], dtype=object)

# %%
f = bd[bd['Gender'] == 'Female']

# %%
f.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11230c290>]], dtype=object)

# %%
 bd.groupby('Gender').mean()
# Out:
#               Freq
# Gender
# Female  152.916667
# Male    224.250000

# %%
bd.groupby('Gender').agg(np.mean)
# Out:
#               Freq
# Gender
# Female  152.916667
# Male    224.250000

# %%
bdf = bd[bd['Gender']== 'Female']

# %%
bdf.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x112457fd0>]], dtype=object)

# %%
bdm = bd[bd['Gender']== 'Male']

# %%
bdm.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x112639890>]], dtype=object)

# %%
bda = bd[bd['Admit']=='Admitted']

# %%
bda.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11272be90>]], dtype=object)

# %%
bdaf = bd[(bd['Admit']=='Admitted') & (bd['Gender'] == 'Female') ]

# %%
bdaf.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1128ef0d0>]], dtype=object)

# %%
bdrf = bd[(bd['Admit']=='Rejected') & (bd['Gender'] == 'Female') ]

# %%
bdrf.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x112b32d90>]], dtype=object)

# %%
bdam = bd[(bd['Admit']=='Admitted') & (bd['Gender'] == 'Male') ]

# %%
bdam.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x112e06fd0>]], dtype=object)

# %%
bdrm = bd[(bd['Admit']=='Rejected') & (bd['Gender'] == 'Male') ]

# %%
bdrm.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x112ef8890>]], dtype=object)
